# %% [markdown]
# <a href="https://colab.research.google.com/github/d0rtilla/AbaloneAgePredictionProject/blob/main/Abalone_Sex_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Abalone Sex Predictor with Supervised Machine Learning
#
# ## Contributors: Jacob Douthett, Sam Espe, Alan Jallah, Jae Neuharth

# %% [markdown]
# ### Extract and Transform Data

# %%
# Import dependencies
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Read in data
file_path = "https://abalone-machine-learning-data.s3.us-east-2.amazonaws.com/abalone.csv"
df = pd.read_csv(file_path)
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
# As the height column shows a 0 which is an indication of missing values, here i used the height column to find the sum of missing values 
(df.Height ==0).sum()
# Out:
# 2

# %%
#Find which column has missing values
df[df['Height']==0]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1257   I   0.430      0.34     0.0         0.428          0.2065
# 3996   I   0.315      0.23     0.0         0.134          0.0575
#
#       Viscera weight  Shell weight  Rings
# 1257          0.0860        0.1150      8
# 3996          0.0285        0.3505      6

# %%
#Find means
means = pd.pivot_table(df, index=['Sex'], aggfunc={'Height':np.mean})
display(means)
# Out:
#        Height
# Sex
# F    0.158011
# I    0.107996
# M    0.151381

# %%
#fill in the missing value with average
df['Height'] = df['Height'].replace(to_replace=0, value=0.0107996)

# %%
# Get dummies on sex column
df = pd.get_dummies(df)
display(df)
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
# ...

# %%
# Rename columns

df = df.rename(columns = {"Whole weight": "Whole_weight", "Shucked weight": "Shucked_weight", "Viscera weight": "Viscera_weight", "Shell weight": "Shell_weight"})
df.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight        Rings        Sex_F        Sex_I  \
# count     4177.000000   4177.000000  4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684     0.312904     0.321283
# ...

# %%
#Drop sex column
X = df.drop(columns = ["Sex_F", "Sex_I", "Sex_M"])
y = df[["Sex_F", "Sex_I", "Sex_M"]]
display(X)
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight  Rings
# ...

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)
#scale datasets
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-360ffa779859> in <module>
#       1 from sklearn import preprocessing
#       2 label_encoder = preprocessing.LabelEncoder()
# ----> 3 y_train = label_encoder.fit_transform(y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     113             Encoded labels.
#     114         """
# --> 115         y = column_or_1d(y, warn=True)
#     116         self.classes_, y = _unique(y, return_inverse=True)
#     117         return y
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#    1037
#    1038     raise ValueError(
# -> 1039         "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1040     )
#    1041
#
# ...

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
# Label encoding
label_encoder = preprocessing.LabelEncoder()
train_Y = label_encoder.fit_transform(y_train)
# Model training
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-35aa8bb39eec> in <module>
#       3 # Label encoding
#       4 label_encoder = preprocessing.LabelEncoder()
# ----> 5 train_Y = label_encoder.fit_transform(y_train)
#       6 # Model training
#       7 clf = LogisticRegression()
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     113             Encoded labels.
#     114         """
# --> 115         y = column_or_1d(y, warn=True)
#     116         self.classes_, y = _unique(y, return_inverse=True)
#     117         return y
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#    1037
#    1038     raise ValueError(
# -> 1039         "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1040     )
#    1041
#
# ...

# %%
regress = LogisticRegression().fit(X_train, y_train)
print( "Logistic Regression score : ", regress.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-53028a41de72> in <module>
# ----> 1 regress = LogisticRegression().fit(X_train, y_train)
#       2 print( "Logistic Regression score : ", regress.score(X_test, y_test))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
# Train a Random Forest Classifier model and print the model score
Random_forest = RandomForestClassifier(random_state=0)
Random_forest.fit(X_train, y_train)
print("RandomForestClassifier score: ", Random_forest.score(X_test, y_test))
# Out:
# RandomForestClassifier score:  0.42488038277511964
